# %% [markdown]
# ---
# title: Week 3.2, Exam Level Assignments
# subtitle: Lecture notes Chemistry for Earth Sciences, week 2
# author:
#   - name: Timo Heimovaara
#     affiliations: Delft University of Technology, department of Geoscience & Engineering
#     orcid:
#     email: t.j.heimovaara@tudelft.nl
# license: CC-BY-NC-ND-4.0 (https://creativecommons.org/licenses/by-nc-nd/4.0/).
# date: 2025-12-04
# file_format: mystnb
# kernelspec:
#   name: python3
# mystnb:
#     execution_mode: 'inline'
# ---

# %% [markdown]
# ##

# %% [markdown]
# ## Exam Level Questions
#
# The assignments in this document are similar level to those of the exam.
# You will not be graded on these assignments, but you use these to assess what you still need to do to be able to answer these question.
# After 30 minutes we will provide you with the solution strategy for these assignments in class
#
# ---
#
# ## Assignment 1: Gibbs Free Energy and Mass Action Law
# ### $\text{CaCO}_3\text[s]$ polymorphs
# In nature we find three main forms of $\text{CaCO}_3\text[s]$ minerals, so-called polymorphs: Calcite, Aragonite and Vaterite.
# The logK values for these minerals are:
# | mineral | logK |
# |---|---|
# |Calcite|-8.48|
# |Aragonite| -8.34|
# |Vaterite| -7.87|
#
# Use the information from Tro, Appendix II to calculate the Gibbs Energy of Formation $\Delta G_f^0$ for these minerals. Please report your answers in kJ/mol.

# %%
# Python cell for Assignment 1:
import numpy as np

# Please make sure you annotate your solution

# %% [markdown]
# ### Gibbs free energies of formation
#
# We start by writing the chemical reaction for the dissolution of Calcite, Aragonite and Vaterite:
# $$
# \text{CaCO}_3\text(s) \leftrightharpoons \text{Ca}^{+2} + \text{CO}_3^{-2}
# $$
#
# As shown in the first tutorial of this week, you can calculate the equilibrium constant for the above equations using the following Gibbs free energies of formation:
#
# Gibbs energies of formation:
# | substance | $\Delta G_f^0$(kJ/mol)|
# | ---|---|
# |$\text{Ca}^{+2}(aq)$| -553.6|
# |$\text{CO}_3^{-2}(aq)$| -527.8|
# |$\text{HCO}_3^-(aq)$| -586.8 |
# |$\text{H}^+(aq)$| 0 |
#
# ### Calculation of Gibbs Free Energy of Formation from K
# Because K is given at equilibrium we can use:
# $$
# \Delta G_{rxn}^0 = -RT \ln K
# $$
#
# And because :
# $$
# \Delta G_{rxn}^0 = \sum_i s_i \Delta {G_f^0}_i
# $$
#
# we get:
# $$
# \Delta {G_f^0}_{Calcite} = -\Delta G_{rxn}^0 + \Delta {G_f^0}_{\text{Ca}^{+2}} +  \Delta {G_f^0}_{\text{CO3}^{-2}}
# $$
#
# or after substitution:
# $$
# \Delta {G_f^0}_{Calcite} = RT \ln K + \Delta {G_f^0}_{\text{Ca}^{+2}} +  \Delta {G_f^0}_{\text{CO3}^{-2}}
# $$
#
# Please note the difference between $\log K$ and $\ln K$!

# %% [markdown]
# ## Assignment 2: Chemical buffers
# A buffer is a chemical solution that resist pH change (Tro chapter 16.2). A buffer contains both a weak acid and its conjugate base.
# At home you can create your own buffer using baking soda (which is $\text{NaHCO}_3$) and washing soda ($\text{Na}_2\text{CO}_3$).
# 1. How many grams of each salt do we need in order to create a solution containing 0.5 mol/liter $\text{NaHCO}_3$ and 0.5 mol per liter $\text{Na}_2\text{CO}_3$?
# 2. What is the pH be of this solution?
# 3. How much HCl or NaOH do you need to add to change the pH by -1 or +1 pH unit?

# %%
# Python cell for Assignment 2:
import numpy as np

# Please make sure you annotate your solution

# %% [markdown]
# ## Answer Assignment 2
# The chemical reaction we are looking at is:
# $$
# \text{HCO}_3^- \leftrightharpoons \text{CO}3^{-2} + \text{H}^+ \qquad K = 10^{-10.3}
# $$
#
# This equation can be rewritten as a function of pH:
# $$
# pH = -\log K + \log \frac{\text{CO}_3^{-2}}{\text{HCO}_3^-}
# $$
#
# answers:
# 1.
# 2. In the initial condition the concentration of the acid and conjugate base are equal, so the pH is 10.3!
# 3. In order to change the pH from 10.3 to 11.3 we need to increase the ratio by a factor of 10, so $[\text{CO}_3^{-2}] = 10 [\times \text{HCO}_3^-]$ and the total amount of $\text{CO}_3^{-2}$ stays 1 mol per liter. So if we set $x = [\text{HCO}_3^-]$ then $x = 1/11$ = 0.091 mol/liter which we can achieve by adding 0.500-0.091 = 0.409 mol $\text{NaOH}$ per liter. For a change in pH from 10.3 to 9.3 we the ratio needs to become 0.1, so $10 [\text{CO}_3^{-2}] = [\times \text{HCO}_3^-]$ which implies that the $[\text{CO}_3^{-2}]$ decreases by a factor of 10. We need to add 0.409 mol/l $\text{HCl}$.
